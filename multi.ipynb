# %%
from qiskit.quantum_info import Statevector, Operator
from numpy import sqrt

# %%
zero = Statevector.from_label("0")
one = Statevector.from_label("1")
psi = zero.tensor(one)

display(psi.draw("latex"))
#or display((zero^one).draw("latex"))
# Out:
# $$ |01\rangle$$
# $$ |01\rangle$$

# %%
a = Statevector.from_label("r")
display(a.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2} i}{2} |1\rangle$$

# %%
H = Operator.from_label("H")
Id = Operator.from_label("I")

display((H.tensor(Id)).draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & \frac{\sqrt{2}}{2} & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & 0 & - \frac{\sqrt{2}}{2} & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
psi = Statevector.from_label("+").tensor(Statevector.from_label("l"))
display(psi.evolve(Operator.from_label("H").tensor(Operator.from_label("I"))).draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2} i}{2} |01\rangle$$

# %%
w = Statevector([0, 1, 1, 0, 1, 0, 0, 0] / sqrt(3))
display(w.draw("latex"))

result, state = w.measure([0])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))
# Out:
# $$\frac{\sqrt{3}}{3} |001\rangle+\frac{\sqrt{3}}{3} |010\rangle+\frac{\sqrt{3}}{3} |100\rangle$$
# Measured: 1
# State after measurement:
# $$ |001\rangle$$

# %%
result, state = w.measure([0, 1])
print(f"Measured: {result}\nState after measurement:")
display(state.draw("latex"))
# Out:
# Measured: 00
# State after measurement:
# $$ |100\rangle$$
